# %%
import pandas as pd

# %%
#loading data(reading data)
stock_broker_data=pd.read_csv('Stock_broker_Quarter_Analysis.csv')

#Give some meaningfull name to dataframe

# %%
stock_broker_data.head()
# Out:
#    Stock_broker_id  Succesful  Knowledge_level  \
# 0              804          1                3
# 1              756          1                2
# 2              470          1                3
# 3              645          1                3
# 4               79          1                2
#
#                               Name     Sex   Age  Certified_trainings_so_far  \
# 0  Thomas, Master. Assad Alexander    male  24.0                           0
# 1        Hamalainen, Master. Viljo    male  24.0                           1
# 2    Baclini, Miss. Helene Barbara  female  24.0                           2
# 3           Baclini, Miss. Eugenie  female  24.0                           2
# 4    Caldwell, Master. Alden Gates    male  24.0                           0
#
#    Increments_so_far Seating_Location Experience_level
# 0                  1              NaN                C
# 1                  1              NaN                S
# ...

# %%
stock_broker_data.columns
# Out:
# Index(['Stock_broker_id', 'Succesful', 'Knowledge_level', 'Name', 'Sex', 'Age',
#        'Certified_trainings_so_far', 'Increments_so_far', 'Seating_Location',
#        'Experience_level'],
#       dtype='object')

# %%
'stock_broker_id'.... unique_ids for each broker

Some information realted to brokers. what is that information?

competency: Knowledge_level, Certified_trainings_so_far

Performances: Increments_so_far, Experience_level
    
Demographic info: Gender Age, Seating location
    
we should identify what we want?

they have collected previous quarter results and data of various brokers

they created successfull column may be some criteria

they have collected,

competency: Knowledge_level, Certified_trainings_so_far

Performances: Increments_so_far, Experience_level
    
Demographic info: Gender Age, Seating location
    
    DATA is ready

# %%
stock_broker_data.shape
# Out:
# (891, 10)

# %%
stock_broker_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Stock_broker_id             891 non-null    int64
#  1   Succesful                   891 non-null    int64
#  2   Knowledge_level             891 non-null    int64
#  3   Name                        891 non-null    object
#  4   Sex                         891 non-null    object
#  5   Age                         714 non-null    float64
#  6   Certified_trainings_so_far  891 non-null    int64
#  7   Increments_so_far           891 non-null    int64
#  8   Seating_Location            204 non-null    object
#  9   Experience_level            889 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 69.7+ KB

# %%
No value in that particula cell: missing value.... null values(NaN, na)

# %%
891-204

#687  null values in Seating location
# Out:
# 687

# %%
891-714

#177 null values in Age

#2 null values in experience level

# %%
stock_broker_data.describe()
# Out:
#        Stock_broker_id   Succesful  Knowledge_level         Age  \
# count       891.000000  891.000000       891.000000  714.000000
# mean        446.000000    0.383838         2.308642   32.747199
# std         257.353842    0.486592         0.836071   11.078334
# min           1.000000    0.000000         1.000000   24.000000
# 25%         223.500000    0.000000         2.000000   24.000000
# 50%         446.000000    0.000000         3.000000   28.000000
# 75%         668.500000    1.000000         3.000000   38.000000
# max         891.000000    1.000000         3.000000   80.000000
#
#        Certified_trainings_so_far  Increments_so_far
# count                  891.000000         891.000000
# mean                     0.523008           0.381594
# std                      1.102743           0.806057
# min                      0.000000           0.000000
# 25%                      0.000000           0.000000
# 50%                      0.000000           0.000000
# ...

# %%
stock_broker_data.head()
# Out:
#    Stock_broker_id  Succesful  Knowledge_level  \
# 0              804          1                3
# 1              756          1                2
# 2              470          1                3
# 3              645          1                3
# 4               79          1                2
#
#                               Name     Sex   Age  Certified_trainings_so_far  \
# 0  Thomas, Master. Assad Alexander    male  24.0                           0
# 1        Hamalainen, Master. Viljo    male  24.0                           1
# 2    Baclini, Miss. Helene Barbara  female  24.0                           2
# 3           Baclini, Miss. Eugenie  female  24.0                           2
# 4    Caldwell, Master. Alden Gates    male  24.0                           0
#
#    Increments_so_far Seating_Location Experience_level
# 0                  1              NaN                C
# 1                  1              NaN                S
# ...

# %%
stock_broker_data_5=stock_broker_data.head()

# %%
stock_broker_data_5.shape
# Out:
# (5, 10)

# %%
stock_broker_data_5
# Out:
#    Stock_broker_id  Succesful  Knowledge_level  \
# 0              804          1                3
# 1              756          1                2
# 2              470          1                3
# 3              645          1                3
# 4               79          1                2
#
#                               Name     Sex   Age  Certified_trainings_so_far  \
# 0  Thomas, Master. Assad Alexander    male  24.0                           0
# 1        Hamalainen, Master. Viljo    male  24.0                           1
# 2    Baclini, Miss. Helene Barbara  female  24.0                           2
# 3           Baclini, Miss. Eugenie  female  24.0                           2
# 4    Caldwell, Master. Alden Gates    male  24.0                           0
#
#    Increments_so_far Seating_Location Experience_level
# 0                  1              NaN                C
# 1                  1              NaN                S
# ...

# %%
stock_broker_data_500=stock_broker_data.head(500)
stock_broker_data_500.shape
# Out:
# (500, 10)

# %%
stock_broker_data_100=stock_broker_data.head(100)

# %%
stock_broker_data_100
# Out:
#     Stock_broker_id  Succesful  Knowledge_level  \
# 0               804          1                3
# 1               756          1                2
# 2               470          1                3
# 3               645          1                3
# 4                79          1                2
# ..              ...        ...              ...
# 95              747          0                3
# 96              765          0                3
# 97              792          0                2
# 98              842          0                2
# 99              854          1                1
#
#                                Name     Sex   Age  Certified_trainings_so_far  \
# 0   Thomas, Master. Assad Alexander    male  24.0                           0
# 1         Hamalainen, Master. Viljo    male  24.0                           1
# 2     Baclini, Miss. Helene Barbara  female  24.0                           2
# ...

# %%
type(stock_broker_data_100)
# Out:
# pandas.core.frame.DataFrame

# %%
stock_broker_data.columns
# Out:
# Index(['Stock_broker_id', 'Succesful', 'Knowledge_level', 'Name', 'Sex', 'Age',
#        'Certified_trainings_so_far', 'Increments_so_far', 'Seating_Location',
#        'Experience_level'],
#       dtype='object')

# %%
stock_broker_data.columns.tolist()

#a list object is created
# Out:
# ['Stock_broker_id',
#  'Succesful',
#  'Knowledge_level',
#  'Name',
#  'Sex',
#  'Age',
#  'Certified_trainings_so_far',
#  'Increments_so_far',
#  'Seating_Location',
#  'Experience_level']

# %%
#columns list
stock_broker_data_col=stock_broker_data.columns.tolist()

# %%
stock_broker_data_col
# Out:
# ['Stock_broker_id',
#  'Succesful',
#  'Knowledge_level',
#  'Name',
#  'Sex',
#  'Age',
#  'Certified_trainings_so_far',
#  'Increments_so_far',
#  'Seating_Location',
#  'Experience_level']

# %%
#anydataset.... do this mandatories

stock_broker_data.head()

stock_broker_data.shape

stock_broker_data.info()

stock_broker_data.columns

stock_broker_data_col=stock_broker_data.columns.tolist()

stock_broker_data.info()

stock_broker_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Stock_broker_id             891 non-null    int64
#  1   Succesful                   891 non-null    int64
#  2   Knowledge_level             891 non-null    int64
#  3   Name                        891 non-null    object
#  4   Sex                         891 non-null    object
#  5   Age                         714 non-null    float64
#  6   Certified_trainings_so_far  891 non-null    int64
#  7   Increments_so_far           891 non-null    int64
#  8   Seating_Location            204 non-null    object
#  9   Experience_level            889 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 69.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# ...

# %%
stock_broker_data
# Out:
#      Stock_broker_id  Succesful  Knowledge_level  \
# 0                804          1                3
# 1                756          1                2
# 2                470          1                3
# 3                645          1                3
# 4                 79          1                2
# ..               ...        ...              ...
# 886              860          0                3
# 887              864          0                3
# 888              869          0                3
# 889              879          0                3
# 890              889          0                3
#
#                                          Name     Sex   Age  \
# 0             Thomas, Master. Assad Alexander    male  24.0
# 1                   Hamalainen, Master. Viljo    male  24.0
# 2               Baclini, Miss. Helene Barbara  female  24.0
# 3                      Baclini, Miss. Eugenie  female  24.0
# 4               Caldwell, Master. Alden Gates    male  24.0
# ...

# %%
stock_broker_data['Age']
# Out:
# 0      24.0
# 1      24.0
# 2      24.0
# 3      24.0
# 4      24.0
#        ...
# 886     NaN
# 887     NaN
# 888     NaN
# 889     NaN
# 890     NaN
# Name: Age, Length: 891, dtype: float64

# %%
['Age','Succesful']
# Out:
# ['Age', 'Succesful']

# %%
stock_broker_data[['Age','Succesful']]
# Out:
#       Age  Succesful
# 0    24.0          1
# 1    24.0          1
# 2    24.0          1
# 3    24.0          1
# 4    24.0          1
# ..    ...        ...
# 886   NaN          0
# 887   NaN          0
# 888   NaN          0
# 889   NaN          0
# 890   NaN          0
#
# [891 rows x 2 columns]

# %%
stock_broker_data['Succesful']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 886    0
# 887    0
# 888    0
# 889    0
# 890    0
# Name: Succesful, Length: 891, dtype: int64

# %%
type(stock_broker_data['Succesful'])
# Out:
# pandas.core.series.Series

# %%
#for how many brokers, data is avaliable with you?

#891

#out of 891 brokers, how many are successful?

#we are choosing successful column from datframe stcok_broker_data using []

stock_broker_data['Succesful']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 886    0
# 887    0
# 888    0
# 889    0
# 890    0
# Name: Succesful, Length: 891, dtype: int64

# %%
stock_broker_data['Succesful'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Succesful, dtype: int64

# %%
#342 brokers are successful out of 891 brokers

# %%
stock_broker_data['Experience_level'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Experience_level, dtype: int64

# %%
#data Dictionary

# %%
stock_broker_data['Increments_so_far'].value_counts()

# 'Increments_so_far' column is having values like 0,1,2,3,4,5,6
#  678 brokers are having 0 Increments_so_far
#  118 brokers are having 1 Increments_so_far
#  80 brokers are having 2 Increments_so_far
#  5 brokers are having 3 Increments_so_far
#  4 brokers are having 4 Increments_so_far
#  5 brokers are having 5 Increments_so_far
#  1 brokers are having 6 Increments_so_far

# how to get unique values of a column... we use value_counts()

# for example.... unique values in this column are 0,1,2,3,4,5,6
# Out:
# 0    678
# 1    118
# 2     80
# 3      5
# 5      5
# 4      4
# 6      1
# Name: Increments_so_far, dtype: int64

# %%
stock_broker_data['Knowledge_level'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Knowledge_level, dtype: int64

# %%
stock_broker_data['Knowledge_level'].value_counts(normalize=True)
# Out:
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: Knowledge_level, dtype: float64

# %%
stock_broker_data['Succesful'].value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Succesful, dtype: float64

# %%
stock_broker_data['Experience_level'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Experience_level, dtype: int64

# %%
stock_broker_data['Experience_level'].value_counts(normalize=True)
# Out:
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: Experience_level, dtype: float64

# %%
stock_broker_data['Certified_trainings_so_far'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: Certified_trainings_so_far, dtype: int64

# %%
stock_broker_data.head(50)
# Out:
#     Stock_broker_id  Succesful  Knowledge_level  \
# 0               804          1                3
# 1               756          1                2
# 2               470          1                3
# 3               645          1                3
# 4                79          1                2
# 5               832          1                2
# 6               306          1                1
# 7               165          0                3
# 8               173          1                3
# 9               184          1                2
# 10              382          1                3
# 11              387          0                3
# 12              789          1                3
# 13              828          1                2
# 14                8          0                3
# 15               17          0                3
# 16              120          0                3
# 17              206          0                3
# ...

# %%
stock_broker_data_Certified_trainings=stock_broker_data.sort_values(by='Certified_trainings_so_far', ascending=False)

# %%
stock_broker_data_Certified_trainings.head(50)
# Out:
#      Stock_broker_id  Succesful  Knowledge_level  \
# 875              793          0                3
# 745              160          0                3
# 884              847          0                3
# 749              181          0                3
# 777              325          0                3
# 755              202          0                3
# 887              864          0                3
# 11               387          0                3
# 75               684          0                3
# 64                60          0                3
# 57               481          0                3
# 83                72          0                3
# 47                51          0                3
# 100               69          1                3
# 53               788          0                3
# 32               172          0                3
# 65               543          0                3
# 41               234          1                3
# ...

# %%
stock_broker_data.sort_values(by='Certified_trainings_so_far')

# %%
stock_broker_data_Increments=stock_broker_data.sort_values(by='Increments_so_far', ascending=False)

stock_broker_data_Increments.head(50)

#we can sort our dataframe based on certain column

# %%
they are two datasets

1)Stock_broker_Quarter_Analysis.csv
2)Stock_broker_Quarter_Analysis_test.csv

# %%
#loading data from two datasets
stock_broker_data=pd.read_csv('Stock_broker_Quarter_Analysis.csv')

stock_broker_data_test=pd.read_csv('Stock_broker_Quarter_Analysis_test.csv')

# %%
stock_broker_data.columns
# Out:
# Index(['Stock_broker_id', 'Succesful', 'Knowledge_level', 'Name', 'Sex', 'Age',
#        'Certified_trainings_so_far', 'Increments_so_far', 'Seating_Location',
#        'Experience_level'],
#       dtype='object')

# %%
['Stock_broker_id', 
 'Succesful', 
 'Knowledge_level',
 'Name',
 'Sex', 
 'Age',
       
 'Certified_trainings_so_far', 
 'Increments_so_far',
 'Seating_Location',
'Experience_level']

# %%
stock_broker_data.shape
# Out:
# (891, 10)

# %%
stock_broker_data_test.shape
# Out:
# (418, 9)

# %%
stock_broker_data_test.columns
# Out:
# Index(['Stock_broker_id', 'Knowledge_level', 'Name', 'Sex', 'Age',
#        'Certified_trainings_so_far', 'Increments_so_far', 'Seating_Location',
#        'Experience_level'],
#       dtype='object')

# %%
['Stock_broker_id', 
 'Knowledge_level', 
 'Name',
 'Sex', 
 'Age',
       
 'Certified_trainings_so_far', 
 'Increments_so_far', 
 'Seating_Location',
'Experience_level']

# %%
#in any Machine Learning you will come accross two datasets, they are

1)Training dataset

2)Test dataset

eg:Training dataset:stock_broker_data
    Test dataset:   stock_broker_data_test

# %%
target variable is present in the training dataset and not present in the test dataset

these target variables are also known as labels or dependent variables

columns other than target(dependent variables) are known as independent variables

in the data we have dependent variable and independent variables

eg:independent variables: 'Stock_broker_id',
'Knowledge_level', 
'Name', 
'Sex', 
'Age',
'Certified_trainings_so_far',
'Increments_so_far', 
'Seating_Location',
'Experience_level'

dependent variable:'Succesful'
    
trainging data:independent variables, dependent variable
    
test data:independent variables

# %%
y=f(x)

eg: y=3x+2

if you know x we can compute y

so to know y we need to know x..... hence y is dependent on x and it is known as dependent variable and x is known as independent variable

y=4x_1+2x_2+3

if you know x_1 and x_2 we can compute y

y is dependent and x_1,x_2 is independent variables

Transfer Functions


the whole objective of ML is learning these transfer functions
