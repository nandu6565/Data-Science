# %%
#Q-1 importing pandas package?
import pandas as pd

# %%
#Q-2 Load Back Order Dataset and create a dataframe having our data?
bo_dev=pd.read_csv('BackOrders_Development.csv')

# %%
#Q-3 Display top 5 rows of the data?
bo_dev.head()
# Out:
#        sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0  1682848            11       12.0               0                 0
# 1  1952807             7        4.0               0                 0
# 2  1990960             1        8.0               0                 8
# 3  3250836            36       12.0               1                 5
# 4  3275747            11        8.0               0                 0
#
#    forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# 0                 0                 0              7             23
# 1                 0                 0              0              0
# 2                 8                 8              1              2
# 3                30                35              8             23
# 4                 6                12              1              5
#
#    sales_6_month  ...  pieces_past_due  perf_6_month_avg perf_12_month_avg  \
# ...

# %%
#Q-4 create a list with all columns of dataframe?
bo_dev.columns.tolist()
# Out:
# ['sku',
#  'national_inv',
#  'lead_time',
#  'in_transit_qty',
#  'forecast_3_month',
#  'forecast_6_month',
#  'forecast_9_month',
#  'sales_1_month',
#  'sales_3_month',
#  'sales_6_month',
#  'sales_9_month',
#  'min_bank',
#  'potential_issue',
#  'pieces_past_due',
#  'perf_6_month_avg',
#  'perf_12_month_avg',
#  'local_bo_qty',
#  'deck_risk',
#  'oe_constraint',
#  'ppap_risk',
#  'stop_auto_buy',
#  'rev_stop',
#  'went_on_backorder']

# %%
#Q-5 Identify Distinct Unique value rates present in 'went_on_backorder'?
bo_dev['went_on_backorder'].value_counts()
# Out:
# No     49455
# Yes    11134
# Name: went_on_backorder, dtype: int64

# %%
#Q-5 Identify Distinct Unique values present in 'went_on_backorder'?
bo_dev['went_on_backorder'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#Q-5 Identify Distinct Unique value rate ratios present in 'went_on_backorder'?
bo_dev['went_on_backorder'].value_counts(normalize=True)
# Out:
# No     0.816237
# Yes    0.183763
# Name: went_on_backorder, dtype: float64

# %%
#Q-6 Sort the DataFrame using national inventory in ascending order?
bo_dev.sort_values(by='national_inv', ascending=True)
# Out:
#            sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 21242  2167348         -2999        9.0               0              5809
# 4666   1963157         -2999        9.0               0              5809
# 32901  1934906         -2036        8.0              36             15000
# 41134  1692064         -1735        8.0              36             15000
# 8513   1447452         -1531        8.0              41             15000
# ...        ...           ...        ...             ...               ...
# 57269  1703208        223840        8.0              10                 0
# 39466  2141951        267222        8.0             900                 0
# 5228   1808102        364065        8.0             250                 0
# 46808  1249018        366924       12.0               0                 0
# 48874  3069067        673445        8.0          170976           1126656
#
#        forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# ...

# %%
#Q-7 Identify dimensions of the data?
bo_dev.shape
# Out:
# (60589, 23)

# %%
#Q-8 Identify datatypes of all columns?
bo_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60589 entries, 0 to 60588
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sku                60589 non-null  int64
#  1   national_inv       60589 non-null  int64
#  2   lead_time          57236 non-null  float64
#  3   in_transit_qty     60589 non-null  int64
#  4   forecast_3_month   60589 non-null  int64
#  5   forecast_6_month   60589 non-null  int64
#  6   forecast_9_month   60589 non-null  int64
#  7   sales_1_month      60589 non-null  int64
#  8   sales_3_month      60589 non-null  int64
#  9   sales_6_month      60589 non-null  int64
#  10  sales_9_month      60589 non-null  int64
#  11  min_bank           60589 non-null  int64
#  12  potential_issue    60589 non-null  object
#  13  pieces_past_due    60589 non-null  int64
#  14  perf_6_month_avg   60589 non-null  float64
#  15  perf_12_month_avg  60589 non-null  float64
# ...

# %%
#Q-9 identify the statistical Information of the columns to explore?
bo_dev.describe()
# Out:
#                 sku   national_inv     lead_time  in_transit_qty  \
# count  6.058900e+04   60589.000000  57236.000000    60589.000000
# mean   2.036394e+06     288.261797      7.555210       30.437472
# std    6.561579e+05    4265.216529      6.485635      799.068768
# min    1.068628e+06   -2999.000000      0.000000        0.000000
# 25%    1.497628e+06       3.000000      4.000000        0.000000
# 50%    1.897487e+06      10.000000      8.000000        0.000000
# 75%    2.314114e+06      57.000000      8.000000        0.000000
# max    3.284895e+06  673445.000000     52.000000   170976.000000
#
#        forecast_3_month  forecast_6_month  forecast_9_month  sales_1_month  \
# count      6.058900e+04      6.058900e+04      6.058900e+04   60589.000000
# mean       1.708265e+02      3.178831e+02      4.575655e+02      45.077869
# std        5.329970e+03      9.854293e+03      1.431812e+04    1385.014961
# min        0.000000e+00      0.000000e+00      0.000000e+00       0.000000
# ...

# %%
#Q-10 Create a Dataframe with all forecast variables?
df=bo_dev[['forecast_3_month','forecast_6_month','forecast_9_month']]
df
# Out:
#        forecast_3_month  forecast_6_month  forecast_9_month
# 0                     0                 0                 0
# 1                     0                 0                 0
# 2                     8                 8                 8
# 3                     5                30                35
# 4                     0                 6                12
# ...                 ...               ...               ...
# 60584                24                24                24
# 60585                40                80               140
# 60586                 0                 0                 0
# 60587                 0                 0                 0
# 60588                 8                 8                 8
#
# [60589 rows x 3 columns]

# %%
#Q-11 create a variable with only one column ‘went_on_backorder’
df=bo_dev[['went_on_backorder']]
df
# Out:
#       went_on_backorder
# 0                    No
# 1                    No
# 2                   Yes
# 3                    No
# 4                    No
# ...                 ...
# 60584                No
# 60585                No
# 60586                No
# 60587               Yes
# 60588               Yes
#
# [60589 rows x 1 columns]

# %%
#Q-12 drop went_on_backorder from the dataframe
df1=bo_dev.drop("went_on_backorder",axis=1)
df1
# Out:
#            sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0      1682848            11       12.0               0                 0
# 1      1952807             7        4.0               0                 0
# 2      1990960             1        8.0               0                 8
# 3      3250836            36       12.0               1                 5
# 4      3275747            11        8.0               0                 0
# ...        ...           ...        ...             ...               ...
# 60584  1397275             6        8.0               0                24
# 60585  3072139           130        2.0               0                40
# 60586  1909363           135        9.0               0                 0
# 60587  1845783            63        NaN               0                 0
# 60588  1200539             0        2.0               0                 8
#
#        forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# ...

# %%
#Q-13 create a variable with only one column ‘sku’
df=bo_dev[['sku']]
df
# Out:
#            sku
# 0      1682848
# 1      1952807
# 2      1990960
# 3      3250836
# 4      3275747
# ...        ...
# 60584  1397275
# 60585  3072139
# 60586  1909363
# 60587  1845783
# 60588  1200539
#
# [60589 rows x 1 columns]

# %%
#Q-14 drop  ‘sku’ from the dataframe
df2=df1.drop("sku",axis=1)
df2
# Out:
#        national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0                11       12.0               0                 0
# 1                 7        4.0               0                 0
# 2                 1        8.0               0                 8
# 3                36       12.0               1                 5
# 4                11        8.0               0                 0
# ...             ...        ...             ...               ...
# 60584             6        8.0               0                24
# 60585           130        2.0               0                40
# 60586           135        9.0               0                 0
# 60587            63        NaN               0                 0
# 60588             0        2.0               0                 8
#
#        forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# 0                     0                 0              7             23
# ...

# %%
#Q-15 After dropping, identify what all columns are present and there count
df2.columns.value_counts()
# Out:
# national_inv         1
# potential_issue      1
# stop_auto_buy        1
# ppap_risk            1
# oe_constraint        1
# deck_risk            1
# local_bo_qty         1
# perf_12_month_avg    1
# perf_6_month_avg     1
# pieces_past_due      1
# min_bank             1
# lead_time            1
# sales_9_month        1
# sales_6_month        1
# sales_3_month        1
# sales_1_month        1
# forecast_9_month     1
# forecast_6_month     1
# forecast_3_month     1
# in_transit_qty       1
# rev_stop             1
# dtype: int64

# %%
#Q-16 create a dataframe with all categorical variables
df3=bo_dev.select_dtypes(include=['object'])
df3
# Out:
#       potential_issue deck_risk oe_constraint ppap_risk stop_auto_buy  \
# 0                  No       Yes            No        No           Yes
# 1                  No       Yes            No        No           Yes
# 2                  No        No            No        No           Yes
# 3                  No        No            No       Yes           Yes
# 4                  No        No            No        No           Yes
# ...               ...       ...           ...       ...           ...
# 60584              No        No            No        No           Yes
# 60585              No        No            No        No           Yes
# 60586              No        No            No       Yes           Yes
# 60587              No        No            No        No            No
# 60588              No       Yes            No        No           Yes
#
#       rev_stop went_on_backorder
# 0           No                No
# 1           No                No
# ...

# %%
#Q-17 create a dataframe with all numerical variables
df4=bo_dev.select_dtypes(include=['int','float'])
df4
# Out:
#            sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0      1682848            11       12.0               0                 0
# 1      1952807             7        4.0               0                 0
# 2      1990960             1        8.0               0                 8
# 3      3250836            36       12.0               1                 5
# 4      3275747            11        8.0               0                 0
# ...        ...           ...        ...             ...               ...
# 60584  1397275             6        8.0               0                24
# 60585  3072139           130        2.0               0                40
# 60586  1909363           135        9.0               0                 0
# 60587  1845783            63        NaN               0                 0
# 60588  1200539             0        2.0               0                 8
#
#        forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# ...
